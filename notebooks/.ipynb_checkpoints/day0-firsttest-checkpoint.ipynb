# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print("loaded")
# Out:
# loaded

# %%
data = {'name': ['Alice', 'Bob', 'Charlie'],
        'age': [25, 30, 35],
        'salary': [50000, 60000, 70000]}
df = pd.DataFrame(data)
df
# Out:
#       name  age  salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   35   70000

# %%
print(f"Average age: {df['age'].mean()}")
print(f"Average salary: ${df['salary'].mean():,.0f}")
# Out:
# Average age: 30.0
# Average salary: $60,000

# %%
df.plot(x='name', y='salary', kind='bar', title='Salaries')
plt.tight_layout()
plt.show()
